# %%
# for print star
#To print star in reverse form
def f(n):
    print('*'*n)
    n-=1
    f(n)
n=int(input('enter num:'))    
fac(n)

# To print star in asending form:
# def fac(n):
#     for i in range(0,n):
#          print('*'*i)
#          i +=1
# n=int(input('enter num:'))    
# fac(n)
# Out:
# enter num:5
# *****
# ****
# ***
# **
# *
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-32-8f2ddb279798> in <module>
#      14     f(n)
#      15 n=int(input('enter num:'))
# ---> 16 fac(n)
#      17
#      18 #Method 2
#
# <ipython-input-31-0ea0043e09c1> in fac(n)
#       2     print('*'*n)
#       3     n-=1
# ----> 4     fac(n)
#       5 n=int(input('enter num:'))
#       6 fac(n)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-31-0ea0043e09c1> in fac(n)
#       2     print('*'*n)
#       3     n-=1
# ----> 4     fac(n)
#       5 n=int(input('enter num:'))
#       6 fac(n)
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
#Telusco
for i in range(5):
    for j in range(i+1):
        print('*',end=' ')
    
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
